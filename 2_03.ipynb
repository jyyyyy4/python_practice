# %%
cart = {"Laptop": 1000000, "Mouse": 15000, "Monitor": 200000, "Pad": 5000}

discounted_cart = {product: int(price * 0.9) for product, price in cart.items() if price >= 50000}

print("--- 할인 적용된 장바구니 (5만원 이상 품목) ---")
print(discounted_cart)
